# %%
#Obter a cidade
i = True                                                          #Teste Cidade
j = True                                                          #Teste Confirmacao
Cidades = ['Porto Alegre', 'Sao Paulo','Belo Horizonte','Fortaleza','Rio de Janeiro','Brasilia','Salvador','Sao Luis','Manaus','Belem','Natal','Recife','Curitiba','Rio Branco','Florianopolis']
while (i == True):
    j = True
    print('--------------------------------------------------------------------------------------------------')
    print('Tabela possiveis cidades:\n1.Porto Alegre\n2.Sao Paulo\n3.Belo Horizonte\n4.Fortaleza\n5.Rio de Janeiro\n6.Brasilia\n7.Salvador\n8.Sao Luis\n9.Manaus\n10.Belem\n11.Natal\n12.Recife\n13.Curitiba\n14.Rio Branco\n15.Florianopolis')
    try:                                                          #Testa a validae do input
        Num = int(input('Escolha a cidade onde estara localizado o predio digitando o numero respectivo a ela: '))   
        if Num < 1 or Num > len(Cidades):
            j = False                                             #Pede uma nova cidade
            print('Cidade não encontrada')
    except:  
        j = False
        print('Cidade não encontrada')
    while (j == True):                                            #Repete enquanto o input não for S ou N
        print('A cidade escolhida foi:', Cidades[Num-1]) 
        Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a cidade escolhida
        if (Confirme == 'S' or Confirme == 's'):                  #Correto
            i = False                                             #Avanca
            j = False
        elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
            j = False
    print('--------------------------------------------------------------------------------------------------')
    
    
print(Cidades[Num-1])
# Out:
# --------------------------------------------------------------------------------------------------
# Tabela possiveis cidades:
# 1.Porto Alegre
# 2.Sao Paulo
# 3.Belo Horizonte
# 4.Fortaleza
# 5.Rio de Janeiro
# 6.Brasilia
# 7.Salvador
# 8.Sao Luis
# 9.Manaus
# 10.Belem
# 11.Natal
# 12.Recife
# 13.Curitiba
# 14.Rio Branco
# 15.Florianopolis
# Escolha a cidade onde estara localizado o predio digitando o numero respectivo a ela: 2
# A cidade escolhida foi: Sao Paulo
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# Sao Paulo

# %%
#Obter Topografia
Topografia = ['Terreno plano ou fracamente acidentado', 'Talude ou morro', 'Vale porfundo, protegido de ventos de qualquer direcao']
i = True                                                          #Teste Topografia
j = True                                                          #Teste Confirmacao
while (i == True):
    j = True
    print('--------------------------------------------------------------------------------------------------')
    print('Tabela possiveis topografias:')
    for k in range(0, 3):
        print(str(k + 1) + '.' + Topografia[k])
    try:                                                          #Testa a validae do input
        Topo = int(input('Escolha a Topografia do local digitando o numero respectivo a ela: '))   
        if Topo < 1 or Topo > len(Topografia):
            j = False                                             #Pede uma nova topografia
            print('Topografia invalida')
    except:  
        j = False
        print('Topografia invalida')
    while (j == True):                                            #Repete enquanto o input não for S ou N
        print('A topografia escolhida foi:', Topografia[Topo-1]) 
        Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a Topografia escolhida
        if (Confirme == 'S' or Confirme == 's'):                  #Correto
            i = False                                             #Avanca
            j = False
        elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
            j = False    
    print('--------------------------------------------------------------------------------------------------')
    
    
print(Topografia[Topo-1])
# Out:
# --------------------------------------------------------------------------------------------------
# Tabela possiveis topografias:
# 1.Terreno plano ou fracamente acidentado
# 2.Talude ou morro
# 3.Vale porfundo, protegido de ventos de qualquer direcao
# Escolha a Topografia do local digitando o numero respectivo a ela: 2
# A topografia escolhida foi: Talude ou morro
# Confirme essa escolha (S/N): ss
# A topografia escolhida foi: Talude ou morro
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# Talude ou morro

# %%
Pos = 0
if Topo == 2:                                                         #Caso seja um talaude
    print('--------------------------------------------------------------------------------------------------')
    print(Topografia[Topo-1],' selecionado, preciso de mais informacões')
    i = True
    j = True
    Posicao = ['Na base do talaude', 'Acima do talaude']
    while (i == True):
        j = True
        print('Tabela possiveis posicões:\n1.Na base do talaude\n2.Acima do talaude')
        try:                                                          #Testa a validae do input
            Pos = int(input('Escolha a posicão do predio: '))   
            if Pos < 1 or Pos > len(Posicao):
                j = False                                             #Pede uma nova posicao
                print('Posicão invalida')
        except:  
            j = False
            print('Posicão invalida')
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A posicao escolhida foi:', Posicao[Pos-1]) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a posicao escolhida
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')

print(Posicao[Pos-1])
# Out:
# --------------------------------------------------------------------------------------------------
# Talude ou morro  selecionado, preciso de mais informacões
# Tabela possiveis posicões:
# 1.Na base do talaude
# 2.Acima do talaude
# Escolha a posicão do predio: 2
# A posicao escolhida foi: Acima do talaude
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# Acima do talaude

# %%
# Obtem informcões caso seja acima 
H_tal = 0                                                             #Altura talaude
Incl = 0                                                              #inclinacão talaude
D_crista = 0                                                          #Distancia da crista
if Pos == 2:                                                          #Caso seja acima
    i = True                                                          #Teste altura
    j = True                                                          #Teste Confirmacao
    H_tal = 0                                                         #Altura talaude
    Incl = 0                                                          #inclinacão talaude
    D_crista = 0                                                      #Distancia da crista
    while (i == True):
        j = True
        print('--------------------------------------------------------------------------------------------------')
        try:                                                          #Testa a validae do input
            H_tal = float(input('Informe a altura do talaude em metros: '))
            if H_tal < 0:
                j = False                                             #Pede uma nova posicao
                print('Altura menor que zero')
        except:  
            j = False
            print('Altura invalida')
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A altura escolhida foi:', H_tal) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a cidade escolhida
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')
    i = True                                                          #Teste inclinacão
    j = True                                                          #Teste Confirmacao
    while (i == True):
        j = True
        print('--------------------------------------------------------------------------------------------------')
        try:                                                          #Testa a validae do input
            Incl = float(input('Informe a inclinacão do talaude em graus: '))
            
            Incl = Incl % 90                                          #Inclinacão menor que 90 e positiva
        
        except:  
            j = False
            print('Inclinacão invalida')
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A inclinacão escolhida foi:', str(Incl) + '°') 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a cidade escolhida
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')
    i = True                                                          #Teste Distancia
    j = True                                                          #Teste Confirmacao
    while (i == True):
        j = True
        print('--------------------------------------------------------------------------------------------------')
        try:                                                          #Testa a validae do input
            D_crista = float(input('Informe a distâcia da crista do talaude em metros: '))
            if D_crista<0:
                j = False                                             #Pede uma nova Distancia            
                print('Distância menor que zero')
        except:  
            j = False
            print('Distância invalida')
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A  a distância da crista escolhida foi:', D_crista) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a cidade escolhida
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')    

    
    print(H_tal, Incl, D_crista)
# Out:
# --------------------------------------------------------------------------------------------------
# Informe a altura do talaude em metros: 15
# A altura escolhida foi: 15.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Informe a inclinacão do talaude em graus: 50
# A inclinacão escolhida foi: 50.0°
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Informe a distâcia da crista do talaude em metros: 20
# A  a distância da crista escolhida foi: 20.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# 15.0 50.0 20.0

# %%
#Obter a rugosidade
i = True                                                          #Teste Rugosidade
j = True                                                          #Teste Confirmacao
Rugosidade = ['Mar calmo', 'Lagos e rios', 'Pântanos sem vegetacão', 'Zona costeira plana', 'Pântano com vegetação rala', 'Campo de aviação', 'Pradaria', 'Fazenda sem sebes ou muros', 'Granjas e casas de campo', 'Fazenda com sebes ou muros', 'Subúrbio a considerável distância do centro, com casas baixas e esparsas', 'Zona de parques e bosques com muitas árvores', 'Cidades pequenas e seus arredores', 'Subúrbio densamente construído de grandes cidades', 'Área industrial plena ou parcialmente desenvolvida', 'Floresta com árvores altas, de copas isoladas', 'Centros de grandes cidades', 'Complexos industriais bem desenvolvidos']
while (i == True):
    j = True
    print('--------------------------------------------------------------------------------------------------')
    for k in range(0, len(Rugosidade)):                           #Tabela
        print(str(k + 1) + '.' + Rugosidade[k])
    try:                                                          #Testa a validae do input
        Rug = int(input('Escolha a rugosidade do terreno digitando o numero respectivo a ela: '))   
        if Rug < 1 or Rug > len(Rugosidade):
            j = False                                             #Pede uma nova Rugosidade
            print('Rugosidade invalida')
    except:  
        j = False
        print('Rugosidade invalida')
    while (j == True):                                            #Repete enquanto o input não for S ou N
        print('A rugosidade escolhida foi:', Rugosidade[Rug-1]) 
        Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a rugosidade escolhida
        if (Confirme == 'S' or Confirme == 's'):                  #Correto
            i = False                                             #Avanca
            j = False
        elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
            j = False
    print('--------------------------------------------------------------------------------------------------')
    
    
print(Rugosidade[Rug-1])
# Out:
# --------------------------------------------------------------------------------------------------
# 1.Mar calmo
# 2.Lagos e rios
# 3.Pântanos sem vegetacão
# 4.Zona costeira plana
# 5.Pântano com vegetação rala
# 6.Campo de aviação
# 7.Pradaria
# 8.Fazenda sem sebes ou muros
# 9.Granjas e casas de campo
# 10.Fazenda com sebes ou muros
# 11.Subúrbio a considerável distância do centro, com casas baixas e esparsas
# 12.Zona de parques e bosques com muitas árvores
# 13.Cidades pequenas e seus arredores
# 14.Subúrbio densamente construído de grandes cidades
# 15.Área industrial plena ou parcialmente desenvolvida
# 16.Floresta com árvores altas, de copas isoladas
# 17.Centros de grandes cidades
# 18.Complexos industriais bem desenvolvidos
# Escolha a rugosidade do terreno digitando o numero respectivo a ela: 16
# A rugosidade escolhida foi: Floresta com árvores altas, de copas isoladas
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# Floresta com árvores altas, de copas isoladas

# %%
#Dimensões predio
l = True
while(l == True):
    i = True
    j = True
    Comprimento_P = 0
    Altura_P = 0
    Largura_P = 0
    while(i == True):                                                 #Obter comprimento
        j = True
        print('--------------------------------------------------------------------------------------------------')
        print('Digite o comprimento (lado maior) do prédio')
        try:                                                          #Testa a validae do input
            Comprimento_P = float(input('Escolha o comprimento do predio em metros: '))   
            if Comprimento_P < 0:
                j = False                                             #Pede um novo comprimento
                print('Comprimento negativo')
        except:  
            j = False
            print('Comprimento invalido')
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('O comprimento escolhido foi:', Comprimento_P) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma o comprimento escolhido
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')
    i = True
    j = True
    while(i == True):                                                 #Obter largura
        j = True
        print('--------------------------------------------------------------------------------------------------')
        print('Digite a largura (lado menor) do prédio')
        try:                                                          #Testa a validae do input
            Largura_P = float(input('Escolha a largura do predio em metros: '))   
            RazaoCL = Comprimento_P/Largura_P
            if Largura_P< 0:
                print('Largura negativa')
                j = False                                             #Pede uma nova largura 
            elif float(RazaoCL) < 1 or float(RazaoCL) > 4:
                print('Proporcões incompativeis: 1 <= Comprimento/Largura <= 4')
                j = False
        except:  
            print('Largura invalida')
            j = False
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A largura escolhido foi:', Largura_P) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a largura escolhido
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')    
    i = True
    j = True
    while(i == True):                                                 #Obter altura
        j = True
        print('--------------------------------------------------------------------------------------------------')
        print('Digite a altura do prédio')
        try:                                                          #Testa a validae do input
            Altura_P = float(input('Escolha a altura do predio em metros: '))   
            RazaoAL = Altura_P/Largura_P
            if Altura_P< 0:
                print('Altra negativa')
                j = False                                             #Pede uma nova largura 
            elif float(RazaoAL) > 6:
                print('Proporcões incompativeis: Altura/Largura <= 6')
                j = False
        except:  
            print('altura invalida')
            j = False
        while (j == True):                                            #Repete enquanto o input não for S ou N
            print('A altura escolhido foi:', Altura_P) 
            Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a altura escolhido
            if (Confirme == 'S' or Confirme == 's'):                  #Correto
                i = False                                             #Avanca
                j = False
            elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
                j = False
        print('--------------------------------------------------------------------------------------------------')    
    i = True
    while (i == True):                                                #Repete enquanto o input não for S ou N
        print('--------------------------------------------------------------------------------------------------')
        print('Comprimento:', Comprimento_P, 'Largura:', Largura_P, 'Altura:', Altura_P) 
        Confirme = str(input('Gostaria de mudar os dados (S/N)? '))   #Confirma a altura escolhido
        if (Confirme == 'N' or Confirme == 'n'):                      #Correto
            i = False                                                 #Avanca
            l = False
        elif(Confirme == 'S' or Confirme == 's'):                     #Errado
            i = False

    
    
print(Comprimento_P, Largura_P, Altura_P)
# Out:
# --------------------------------------------------------------------------------------------------
# Digite o comprimento (lado maior) do prédio
# Escolha o comprimento do predio em metros: 20
# O comprimento escolhido foi: 20.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a largura (lado menor) do prédio
# Escolha a largura do predio em metros: 10
# A largura escolhido foi: 10.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a altura do prédio
# Escolha a altura do predio em metros: 30
# A altura escolhido foi: 30.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Comprimento: 20.0 Largura: 10.0 Altura: 30.0
# Gostaria de mudar os dados (S/N)? s
# --------------------------------------------------------------------------------------------------
# Digite o comprimento (lado maior) do prédio
# Escolha o comprimento do predio em metros: 15
# O comprimento escolhido foi: 15.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a largura (lado menor) do prédio
# Escolha a largura do predio em metros: 20
# Proporcões incompativeis: 1 <= Comprimento/Largura <= 4
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a largura (lado menor) do prédio
# Escolha a largura do predio em metros: s
# Largura invalida
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a largura (lado menor) do prédio
# Escolha a largura do predio em metros: 15
# A largura escolhido foi: 15.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Digite a altura do prédio
# Escolha a altura do predio em metros: 15
# A altura escolhido foi: 15.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Comprimento: 15.0 Largura: 15.0 Altura: 15.0
# Gostaria de mudar os dados (S/N)? n
# 15.0 15.0 15.0

# %%
i = True
j = True
Pav_Calc = 0
while(i == True):                                                 #Obter comprimento
    j = True
    print('--------------------------------------------------------------------------------------------------')
    print('Digite a altura onde será calculada a carga do vento sobre a edificacão ')
    try:                                                          #Testa a validae do input
        Pav_Calc = float(input('Escolha a altura onde sera calculado em metros: '))   
        if Pav_Calc <= 0 or Pav_Calc > Altura_P:
            j = False                                             #Pede um novo comprimento
            print('Altura invalida')
    except:  
        j = False
        print('Altura invalido')
    while (j == True):                                            #Repete enquanto o input não for S ou N
        print('O Altura escolhido foi:', Pav_Calc) 
        Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma o comprimento escolhido
        if (Confirme == 'S' or Confirme == 's'):                  #Correto
            i = False                                             #Avanca
            j = False
        elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
            j = False
    print('--------------------------------------------------------------------------------------------------')

    
print(Pav_Calc)
# Out:
# --------------------------------------------------------------------------------------------------
# Digite a altura onde será calculada a carga do vento sobre a edificacão
# Escolha a altura onde sera calculado em metros: 10
# O Altura escolhido foi: 10.0
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------
# 10.0

# %%
Seguranca = ['Hospital, quartel de bombeiros e de forças de segurança, centrais de comunicação ou afins', 'Edificação residencial, hotel, comercial ou industrial com alto fator de ocupação', 'Edificação industrial com baixo fator de ocupação (silos, depósitos, construções rurais e afins)', 'Edificação temporária']
i = True                                                          #Teste Seguranca
j = True                                                          #Teste Confirmacao
while (i == True):
    j = True
    print('--------------------------------------------------------------------------------------------------')
    print('Tabela possíveis graus de seguranca:')
    for k in range(0, 4):
        print(str(k + 1) + '.' + Seguranca[k])
    try:                                                          #Testa a validae do input
        Grau_Seg = int(input('Escolha o grau de seguranca digitando o numero respectivo a ela: '))   
        if Grau_Seg < 1 or Grau_Seg > len(Seguranca):
            j = False                                             #Pede uma nova seguranca
            print('Grau de seguranca invalido')
    except:  
        j = False
        print('Grau de seguranca invalido')
    while (j == True):                                            #Repete enquanto o input não for S ou N
        print('O Grau de seguranca escolhida foi:',Seguranca[Grau_Seg-1]) 
        Confirme = str(input('Confirme essa escolha (S/N): '))    #Confirma a seguranca escolhida
        if (Confirme == 'S' or Confirme == 's'):                  #Correto
            i = False                                             #Avanca
            j = False
        elif(Confirme == 'N' or Confirme == 'n'):                 #Errado
            j = False    
    print('--------------------------------------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------------------------------------
# Tabela possíveis graus de seguranca:
# 1.Hospital, quartel de bombeiros e de forças de segurança, centrais de comunicação ou afins
# 2.Edificação residencial, hotel, comercial ou industrial com alto fator de ocupação
# 3.Edificação industrial com baixo fator de ocupação (silos, depósitos, construções rurais e afins)
# 4.Edificação temporária
# Escolha o grau de seguranca digitando o numero respectivo a ela: 5
# Grau de seguranca invalido
# --------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------
# Tabela possíveis graus de seguranca:
# 1.Hospital, quartel de bombeiros e de forças de segurança, centrais de comunicação ou afins
# 2.Edificação residencial, hotel, comercial ou industrial com alto fator de ocupação
# 3.Edificação industrial com baixo fator de ocupação (silos, depósitos, construções rurais e afins)
# 4.Edificação temporária
# Escolha o grau de seguranca digitando o numero respectivo a ela: 2
# O Grau de seguranca escolhida foi: Edificação residencial, hotel, comercial ou industrial com alto fator de ocupação
# Confirme essa escolha (S/N): s
# --------------------------------------------------------------------------------------------------

# %%
Lista_V0 = [50, 40, 30, 30, 35, 35, 30, 30, 35, 35, 30, 30, 45, 30, 45]         #Checa na lista conforme a cidade #Checar BH
print(Lista_V0[Num - 1], Num, Cidades[Num - 1])
# Out:
# 40 2 Sao Paulo

# %%
S1 = 0

if (Topo == 1): #se o terreno for plano ou fracamente acidentado
    S1 = 1.0
elif (Topo == 2): #talude ou morro
    if (Pos == 1): #edificação na base do talude
        S1 = 1.0
    elif (Pos == 2): #edificação no topo do talude
        if (Incl <= 3): #angulo menor ou igual a 3
            S1 = 1.0
        elif (Incl>=6 and Incl<=17): #angulo maior ou igual a 6 e menor ou igual a 17
            S1 = 1.0 + (2.5 - Pav_Calc / H_tal) * np.tan(Incl * np.pi / 180 - 3 * np.pi / 180) #pi/180 para transformar em radianos para o cálculo
            if (S1 < 1): #se o resultado for menor que 1, vale 1
                S1 = 1.0 #é isso?
        elif (Incl>=45): #inclinação maior ou igual a 45
            S1 = 1.0 + (2.5 - Pav_Calc / H_tal) * 0.31
            if (S1 < 1): #se o resultado for menor que 1, vale 1
                S1 = 1.0 #é isso?
        elif (Incl < 6 and Incl > 3): #interpolação linear
            S1 = (( 1.0 + (2.5 - Pav_Calc / H_tal) * np.tan(6 * np.pi / 180 -3 * np.pi / 180) - 1 ) * (Incl - 3)) / 3
        elif (Incl < 17 and Incl > 45): #interpolação linear
            S1 = (1.0 + (2.5 - Pav_Calc / H_tal) * np.tan(17 * np.pi / 180 - 3 * np.pi / 180) + 1.0 + (2.5 - Pav_Calc / H_tal) * 0.31) * (Incl - 17) / 28
        if (4 *  H_tal <= D_crista):
            S1 = 1
        if(D_crista > 0 and D_crista < 4 *  H_tal): 
            print(S1)
            S1 = 1 + ((S1 - 1) * D_crista / (H_tal * 4))
            print(S1)
else:
    S1 = 0.9
print (np.round(S1, 2))
# Out:
# 1.5683333333333334
# 1.1894444444444445
# 1.19

# %%
print(Cidades[Num-1])
print(Topografia[Topo-1])
print(Posicao[Pos-1])
print(H_tal, Incl, D_crista)
print(Rugosidade[Rug-1])
print(Comprimento_P, Largura_P, Altura_P)
print(Pav_Calc)
print(Seguranca[Grau_Seg-1])
# Out:
# Sao Paulo
# Talude ou morro
# Acima do talaude
# 15.0 50.0 20.0
# Floresta com árvores altas, de copas isoladas
# 15.0 15.0 15.0
# 10.0
# Edificação residencial, hotel, comercial ou industrial com alto fator de ocupação

# %%
#9 CÁLCULO DE S2
#definição de categoria

if (Rug==1 or Rug==2 or Rug==3):
    categ = 'I'

elif (Rug==4 or Rug==5 or Rug==6 or Rug==7 or Rug==8):
    categ = 'II'
elif (Rug==9 or Rug==10 or Rug==11):
    categ = 'III'
elif (Rug==12 or Rug==13 or Rug==14 or Rug==15):
    categ = 'IV'

else: #pode ser usado apenas o else, porque no código 3 eu ja delimitei os valores entre 1 e 18
    categ = 'V'
   
        #definição de classe
Fr = 0.0
S2 = 0.0
Btab = 0.0
p = 0.0

if (Comprimento_P <= 20 and Altura_P <= 20):
    Fr = 1.00
    classe = 'A'
elif (max(Comprimento_P,Altura_P) > 20 or max(Comprimento_P,Altura_P) <= 50):
    Fr = 0.98
    classe = 'B'
elif (Comprimento_P > 50 or Altura_P > 50):
    Fr = 0.95
    classe = 'C'
if (categ == 'I'):
    if (classe == 'A'): #não precisava ter definido a variavel classe pois o fr ja tem essa utilidade, mas quis deixar mais organizado, apesar de redundante
        Btab = 1.10
        p = 0.06
    elif (classe == 'B'):
        Btab = 1.1
        p = 0.065
    else: #classe C, pois só ta usando os valores q eu tinha delimitado no começo
        Btab = 1.1
        p = 0.065

if (categ == 'II'):
    if (classe == 'A'):
        Btab = 1.0
        p = 0.085
    elif (classe == 'B'):
        Btab = 1.0
        p = 0.09
    else:
        Btab = 1.0
        p = 0.1

if (categ == 'III'):
    if (classe == 'A'):
        Btab = 0.94
        p = 0.1
    elif (classe == 'B'):
        Btab = 0.94
        p = 0.105
    else:
        Btab = 0.93
        p = 0.115
if (categ == 'IV'):
    if (classe == 'A'):
        Btab = 0.86
        p = 0.12
    elif (classe == 'B'):
        Btab = 0.85
        p = 0.125
    else:
        Btab = 0.84
        p = 0.135
if (categ == 'V'):
    if (classe == 'A'):
        Btab = 0.74
        p = 0.15
    elif (classe == 'B'):
        Btab = 0.73
        p = 0.16
    else:
        Btab = 0.71
        p = 0.175
S2 = Btab * Fr*(H_tal /10)**p

print(S2, Btab, Fr, p, classe, categ)
# Out:
# 0.7864034472560342 0.74 1.0 0.15 A V

# %%
#10 CÁLCULO DE S3
S3 = 0.0
if (Grau_Seg==1):
    S3 = 1.10
elif (Grau_Seg==2):
    S3 = 1.00
elif (Grau_Seg==3):
    S3 = 0.95
else:
    S3 = 0.83
print('O valor de S3 é ',S3)
# Out:
# O valor de S3 é  1.0

# %%
import numpy as np
Vento0 = np.array([[[-0.8, -0.5, 0.7, -0.4],[-0.8, -0.4, 0.7, -0.3]],
                   [[-0.9, -0.5, 0.7, -0.5],[-0.9, -0.4, 0.7, -0.3]],
                   [[-1, -0.6, 0.8, -0.6], [-1, -0.5, 0.8, -0.3]]])            #Lista Vento a 0
Vento90 = np.array([[[0.7, -0.4, -0.8, -0.4], [0.7, -0.5, -0.9, -0.5]],
                    [[0.7, -0.5, -0.9, -0.5], [0.7, -0.6, -0.9, -0.5]],
                    [[0.8, -0.6, -1, -0.6], [0.8, -0.6, -1, -0.6]]])
print(Vento90[0,0,:],'\n \n \n')
print(Vento0[0,0,:] - Vento0[0,1,:])
# Out:
# [ 0.7 -0.4 -0.8 -0.4]
#
#
#
# [ 0.  -0.1  0.  -0.1]

# %%
if(Altura_P/Largura_P <= 0.5):
    if (Comprimento_P / Largura_P <=1.5 and Comprimento_P / Largura_P >= 1):
        RVento0 = Vento0[0,0,:]
        RVento90 = Vento90[0,0,:]
    if (Comprimento_P / Largura_P <=4 and Comprimento_P / Largura_P >= 2):
        RVento0 = Vento0[0,1,:]
        RVento90 = Vento90[0,1,:]
    else:
        RVento0 = Vento0[0,0,:] + (Vento0[0,1,:] - Vento0[0,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5
        RVento90 = Vento90[0,0,:] + (Vento90[0,1,:] - Vento90[0,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5
if(Altura_P/Largura_P >= 0.5 and Altura_P/Largura_P <= 1.5):
    if (Comprimento_P / Largura_P <=1.5 and Comprimento_P / Largura_P >= 1):
        RVento0 = Vento0[1,0,:]
        RVento90 = Vento90[1,0,:]
    if (Comprimento_P / Largura_P <=4 and Comprimento_P / Largura_P >= 2):
        RVento0 = Vento0[1,1,:]
        RVento90 = Vento90[1,1,:]
    else:
        RVento0 = Vento0[1,0,:] + (Vento0[1,1,:] - Vento0[1,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5
        RVento90 = Vento90[1,0,:] + (Vento90[1,1,:] - Vento90[1,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5
if(Altura_P/Largura_P >= 1.5 and Altura_P/Largura_P <= 6):
    if (Comprimento_P / Largura_P <=1.5 and Comprimento_P / Largura_P >= 1):
        RVento0 = Vento0[2,0,:]
        RVento90 = Vento90[2,0,:]
    if (Comprimento_P / Largura_P <=4 and Comprimento_P / Largura_P >= 2):
        RVento0 = Vento0[2,1,:]
        RVento90 = Vento90[2,1,:]
    else:
        RVento0 = Vento0[2,0,:] + (Vento0[2,1,:] - Vento0[2,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5
        RVento90 = Vento90[2,0,:] + (Vento90[2,1,:] - Vento90[2,0,:]) * (Comprimento_P / Largura_P - 1.5) / 0.5

RVento90 = RVento90 * q
RVento0 = RVento0 * q
AB3 = Comprimento_P / 2
if(Comprimento_P / 4 < Largura_P / 3):
    AB1 = Comprimento_P / 4
else:
    AB1 = Largura_P / 3
if(AB1 >= 2*Pav_Calc):
    AB1 = 2*Pav_Calc
AB2 = Comprimento_P * 0.5 - AB1
CD = Largura_P
AB = Comprimento_P
if(2 * Pav_Calc < Largura_P / 2):
    CD1 = 2 * Pav_Calc
else:
    CD1 =Largura_P / 2
CD2 = Largura_P - CD1
if(Comprimento_P / Largura_P == 1):
    CeA3 = Vento0[1]
if(Comprimento_P / Largura_P >= 2):
    CeA3 = -0.2 *q
else:
    CeA3 = RVento0[1] + (((-0.2) * q) - RVento0[1]) * ((Comprimento_P / Largura_P) - 1)

# %%
print(RVento0)
print(RVento90)
CeA3
# Out:
# [-0.9 -0.6  0.7 -0.7]
# [ 0.7 -0.4 -0.9 -0.5]
# -0.6

# %%
import matplotlib.pyplot as plt

x = [1, 2, 2, 1, 1]
y = [1, 1, 2, 2, 1]
plt.plot(x,y)
plt.annotate(text='q = 100 N/m²',xy=(1.5,1.5),fontsize=20.0)
plt.annotate(text='q = 200 N/m²',xy=(1.7,1.9),fontsize=10.0)
plt.annotate(text='q = 300 N/m²',xy=(1.0,1.1),fontsize=8.0)
plt.show()
plt.subplots(figsize=(b/2**valor, a/2**valor))

# %%
q =1

# %%
#8 CÁLCULOS DE S1
import numpy as np

S1 = 0

if (topo == 1): #se o terreno for plano ou fracamente acidentado
    S1 = 1.0
elif (topo == 2): #talude ou morro
    if (onde == 1): #edificação na base do talude
        S1 = 1.0
    elif (onde == 2): #edificação no topo do talude
        if (incl <= 3): #angulo menor ou igual a 3
            S1 = 1.0
        elif (incl>=6 and incl<=17): #angulo maior ou igual a 6 e menor ou igual a 17
            S1 = 1.0 + (2.5 - z / d) * np.tan (incl * np.pi / 180 - 3 * np.pi / 180) #pi/180 para transformar em radianos para o cálculo
            if (S1 < 1): #se o resultado for menor que 1, vale 1
                S1 = 1.0 #é isso?
        elif (incl>=45): #inclinação maior ou igual a 45
            S1 = 1.0 + (2.5 - z / d) * 0.31
            if (S1 < 1): #se o resultado for menor que 1, vale 1
                S1 = 1.0 #é isso?
        elif (incl < 6 and incl > 3): #interpolação linear
            S1 = (( 1.0 + (2.5 - z / d) * np.tan * (6 * np.pi / 180 -3 * np.pi / 180) - 1 ) * (incl - 3)) / 3
        elif (incl < 17 and incl > 45): #interpolação linear
            S1 = (1.0 + (2.5 - z / d) * np.tan (17 * np.pi / 180 - 3 * np.pi / 180) + 1.0 + (2.5 - z / d) * 0.31) * (incl - 17) / 28
        if (4 * d <= l):
            S1 = 1
        if(l > 0 and l < 4 *  d): 
            print(S1)
            S1 = 1 + ((S1 - 1) * l / (d * 4))
            print(S1)
else:
    S1 = 0.9
print (np.round(S1, 4))
