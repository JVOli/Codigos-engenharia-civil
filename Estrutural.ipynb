# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

# %%
F = float(input('fc = '))
E = float(input('ec^2/2 = '))
S = float(input('sigma crit = '))
precisao = int(input('numero de pontos = '))
xmax = S+1
X = np.arange(0,xmax,xmax/precisao)
Fx = np.zeros(precisao)
for i in range(1,precisao-1):
    Fx[i] = F/X[i] - (1+E*1/cos(pi/2*(X[i]/S)**(1/2)))
for i in range(1,precisao-2):
    if(Fx[i]*Fx[i+1] <= 0):
        valor = X[i]
        print('σcrit = ', X[i])
        break
zerro = np.zeros(precisao)
plt.subplots(figsize=(10,10)) 
plt.xlim(valor-(xmax/10),valor+(xmax/10))
plt.ylim(-10,10)
plt.plot(X, zerro)
txt = 'sigma crit = '+str(np.round(valor,3))
plt.plot(X, Fx, label = txt)
plt.legend()
plt.show
# Out:
# fc = 250
# ec^2/2 = 0.4955
# sigma crit = 71.9
# numero de pontos = 10000
# σcrit =  58.626180000000005
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
m = ar+p
H = (ag/c)/(1+m)*100
alpha = (1+ar)/(1+m)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-55c494c9915d> in <module>
# ----> 1 m = c+p
#       2 H = (a/c)/(1+m)*100
#       3 alpha = (1+a)/(1+c)*100
#
# NameError: name 'c' is not defined

# %%
Fx
# Out:
# array([           inf, 3.42934033e+05, 1.71466269e+05, ...,
#        4.80479612e+01, 4.80147382e+01, 0.00000000e+00])

# %%
plt.subplots(figsize=(10,10)) 
plt.xlim(0,valor+(xmax/10))
plt.ylim(-10,100)
plt.plot(X, zerro)
textcea2 = str('sigma crit = '+str(valor))
plt.plot(X, Fx, label=textcea2, )
plt.legend()
plt.show()

# %%
# Out:
# fck = 25
# desvio = 3
# 0.557

# %%
plt.subplots(figsize=(10,10)) 
plt.plot(x, zero)
plt.plot(x, fc28, label = 'fc28')
plt.legend()
plt.show()

# %%
np.log(e)
# Out:
# 1.0
